# %%
import os
import pandas as pd
import numpy as np
import scipy

from auditory_cortex.analyses import Correlations
from auditory_cortex import saved_corr_dir, results_dir
from auditory_cortex.neural_data.normalizer import Normalizer
from auditory_cortex.dataloader import DataLoader
from auditory_cortex.io_utils import io

import matplotlib.pylab as plt
# %matplotlib inline

dataloader = DataLoader()
# Out:
# 2024-06-12 14:55:57.316339: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
session = 200206
bin_width = 50
sent_ids = [12]
ch = 32
# Out:
# NeuralData:  Creating object for session: 200206 ... Done.

# %%
delay=0
all_trials = dataloader.get_neural_data_for_repeated_trials(
		session, bin_width=bin_width, delay=delay,
		sent_IDs=sent_ids
	)
num_bins = all_trials.shape[1]
ticks = np.arange(0, num_bins, 5)
for tr in range(all_trials.shape[0]):
	plt.plot(all_trials[tr,...,ch], color='gray')
plt.plot(np.mean(all_trials[...,ch], axis=0), color='k')
plt.xticks(ticks, ticks*50)
plt.title(f"delay={delay}ms")
plt.show()

# %%
delay=250
all_trials = dataloader.get_neural_data_for_repeated_trials(
		session, bin_width=bin_width, delay=delay,
		sent_IDs=sent_ids
	)
num_bins = all_trials.shape[1]
ticks = np.arange(0, num_bins, 5)
for tr in range(all_trials.shape[0]):
	plt.plot(all_trials[tr,...,ch], color='gray')
plt.plot(np.mean(all_trials[...,ch], axis=0), color='k')
plt.xticks(ticks, ticks*50)
plt.title(f"delay={delay}ms")
plt.show()

# %%
delay=500
all_trials = dataloader.get_neural_data_for_repeated_trials(
		session, bin_width=bin_width, delay=delay,
		sent_IDs=sent_ids
	)
num_bins = all_trials.shape[1]
ticks = np.arange(0, num_bins, 5)
for tr in range(all_trials.shape[0]):
	plt.plot(all_trials[tr,...,ch], color='gray')
plt.plot(np.mean(all_trials[...,ch], axis=0), color='k')
plt.xticks(ticks, ticks*50)
plt.title(f"delay={delay}ms")
plt.show()

# %%
ticks
# Out:
# array([ 0, 10, 20])

# %%
all_trials.shape
# Out:
# (11, 27, 64)
