# %%
import numpy as np
import scipy as sp

import matplotlib.pyplot as plt

# %%
g_1 = np.random.normal(1,1, size=(100,))
g_2 = np.random.normal(10,10, size=(100,))

plt.hist(g_1, label='one')
plt.figure()
plt.hist(g_2, label='two')
# plt.legend()
plt.show()
