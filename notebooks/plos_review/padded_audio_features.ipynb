# %%
# ------------------  set up logging ----------------------
import logging
from auditory_cortex.utils import set_up_logging
set_up_logging('info')

import os
import scipy
import numpy as np
import seaborn as sns
from functools import reduce

from auditory_cortex.plotters import tikzplots
from auditory_cortex.analyses import Correlations, STRFCorrelations
from auditory_cortex.plotters.correlation_plotter import RegPlotter
from auditory_cortex.plotters.plotter_utils import PlotterUtils

import matplotlib.pylab as plt
import matplotlib as mpl
# %matplotlib inline
# Out:
# INFO:Please install tensorboardX: pip install tensorboardX
# WARNING:SoX could not be found!
#
#     If you do not have SoX, proceed here:
#      - - - http://sox.sourceforge.net/ - - -
#
#     If you do (or think that you should) have SoX, double-check your
#     path variables.
# /bin/sh: line 1: sox: command not found
# /home/ahmedb/projects/Wav2Letter/deepspeech.pytorch/deepspeech_pytorch/loader/data_loader.py:17: UserWarning: torchaudio._backend.set_audio_backend has been deprecated. With dispatcher enabled, this function is no-op. You can remove the function call.
#   torchaudio.set_audio_backend("sox_io")

# %%
threshold=0.5
save_tikz = False

# %% [markdown]
# ### timit

# %%
from auditory_cortex.plotters.tikzplots import plot_trained_vs_shuffled_network_results
model_names = [
    'whisper_tiny',
    'whisper_base',
    'wav2letter_modified',
    'wav2vec2',
    'speech2text',
    'deepspeech2',
    ]
bin_width = 50
trained_identifier = 'ucsf_timit_trf_lags200_bw50_regression_improved'
untrained_identifiers = [f'ucsf_reset_timit_trf_lags200_bw50_regression_improved']
tikz_indicator = 'trf'
baseline_identifier = f"mel_wh_ucsf_timit_trf_lags200_bw50_regression_improved"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
if 'mVocs' in trained_identifier:
	mVocs=True
else:
	mVocs=False
normalized=True
plot_trained_vs_shuffled_network_results(
		model_names=model_names,
		normalized=normalized,
		threshold=threshold,
		untrained_identifiers = untrained_identifiers,
		trained_identifier = trained_identifier,
		# areas = ['core', 'belt', 'parabelt'],
		baseline_identifier=baseline_identifier,
		indicate_significance=True,
		plot_difference=False,
		display_dotted_lines=False,
		mVocs=mVocs,
		save_tikz=save_tikz,
		arch_ind_lw=8,
		sig_ind_size=1,
		tikz_indicator=tikz_indicator,
		bin_width=bin_width,
		plot_baseline=True,
		use_stat_inclusion=False,
)
# Out:
# INFO:Plotting trained and shuffled distributions for whisper_tiny
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels returned: (404,)
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Peak corr (median): 0.5924593921399006, occurs at x_coordinate: 2
# INFO:Peak corr (max): 0.9298824673090876, occurs at x_coordinate: 2
# INFO:Peak corr (median): 0.5649088303558862, occurs at x_coordinate: 1
# INFO:Peak corr (max): 0.8780196615200477, occurs at x_coordinate: 2
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5320433926375367, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.8513346902012414, occurs at x_coordinate: 0
# INFO:Plotting trained and shuffled distributions for whisper_base
# INFO:Extracting column: normalized_test_cc
# ...

# %% [markdown]
# ### mVocs

# %%
from auditory_cortex.plotters.tikzplots import plot_trained_vs_shuffled_network_results
model_names = [
    'whisper_tiny',
    'whisper_base',
    'wav2letter_modified',
    'wav2vec2',
    'speech2text',
    'deepspeech2',
    ]
bin_width = 50
trained_identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved'
untrained_identifiers = [f'ucsf_reset_mVocs_trf_lags200_bw50_regression_improved']
tikz_indicator = 'trf'
baseline_identifier = f"mel_wh_ucsf_mVocs_trf_lags200_bw50_regression_improved"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
if 'mVocs' in trained_identifier:
	mVocs=True
else:
	mVocs=False
normalized=True
plot_trained_vs_shuffled_network_results(
		model_names=model_names,
		normalized=normalized,
		threshold=threshold,
		untrained_identifiers = untrained_identifiers,
		trained_identifier = trained_identifier,
		# areas = ['core', 'belt', 'parabelt'],
		baseline_identifier=baseline_identifier,
		indicate_significance=True,
		plot_difference=False,
		display_dotted_lines=False,
		mVocs=mVocs,
		save_tikz=save_tikz,
		arch_ind_lw=8,
		sig_ind_size=1,
		tikz_indicator=tikz_indicator,
		bin_width=bin_width,
		plot_baseline=True,
		use_stat_inclusion=False,
)
# Out:
# INFO:Plotting trained and shuffled distributions for whisper_tiny
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels returned: (489,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Peak corr (median): 0.6861649562152975, occurs at x_coordinate: 1
# INFO:Peak corr (max): 1.1511884430438055, occurs at x_coordinate: 0
# INFO:Peak corr (median): 0.6596580425215479, occurs at x_coordinate: 1
# INFO:Peak corr (max): 1.1381406993585104, occurs at x_coordinate: 0
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.6383805086688307, occurs at x_coordinate: 0
# INFO:Peak corr (max): 1.1338477393284758, occurs at x_coordinate: 0
# INFO:Plotting trained and shuffled distributions for whisper_base
# ...

# %% [markdown]
# ### speech2text, mVocs

# %%
from auditory_cortex.plotters.tikzplots import plot_trained_vs_shuffled_network_results
model_names = [
    # 'whisper_tiny',
    # 'whisper_base',
    # 'wav2letter_modified',
    # 'wav2vec2',
    'speech2text',
    # 'deepspeech2',
    ]
bin_width = 50
trained_identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved_lmbda15'
untrained_identifiers = [f'ucsf_reset_mVocs_trf_lags200_bw50_regression_improved']
tikz_indicator = 'trf'
# baseline_identifier = f"mel_wh_ucsf_mVocs_trf_lags200_bw50_regression_improved"
baseline_identifier = f"mel_ucsf_mVocs_trf_lags200_bw50_regression_improved"
# baseline_identifier = "mel_ucsf_mVocs_trf_lags200_bw50_regression_improved_lmbda_wide"
baseline_identifier = 'STRF_freqs80_'+baseline_identifier
if 'mVocs' in trained_identifier:
	mVocs=True
else:
	mVocs=False
normalized=True
plot_trained_vs_shuffled_network_results(
		model_names=model_names,
		normalized=normalized,
		threshold=threshold,
		untrained_identifiers = untrained_identifiers,
		trained_identifier = trained_identifier,
		# areas = ['core', 'belt', 'parabelt'],
		baseline_identifier=baseline_identifier,
		indicate_significance=True,
		plot_difference=False,
		display_dotted_lines=False,
		mVocs=mVocs,
		save_tikz=save_tikz,
		arch_ind_lw=8,
		sig_ind_size=1,
		tikz_indicator=tikz_indicator,
		bin_width=bin_width,
		plot_baseline=True,
		use_stat_inclusion=False,
)
# Out:
# INFO:Plotting trained and shuffled distributions for speech2text
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Number of channels returned: (489,)
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Peak corr (median): 0.6332874887628928, occurs at x_coordinate: 7
# INFO:Peak corr (max): 0.9671988237168756, occurs at x_coordinate: 11
# INFO:Peak corr (median): 0.5665699942977034, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.97002109124875, occurs at x_coordinate: 6
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# model_name 'baseline' not recognizable!!!
# INFO:Peak corr (median): 0.5787000061710474, occurs at x_coordinate: 0
# INFO:Peak corr (max): 0.9419145339010592, occurs at x_coordinate: 0

# %%
fig, ax = plt.subplots()
model_name = 'speech2text'
identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved_lmbda15'
threshold = 0.5
mVocs = True
lmbda_column = 'opt_lmbda'
corr_column = 'mVocs_normalized_test_cc'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
ax.scatter(data[lmbda_column], data[corr_column])
ax.axhline(0, color='black', linestyle='--')
ax.set_ylim(-0.5, 2)
ax.set_xlim(-5, 15)
ax.set_title(model_name)
# Out:
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# Text(0.5, 1.0, 'speech2text')

# %% [markdown]
# ### regularization...

# %%
model_names = [
    'whisper_tiny',
    # 'whisper_base',
    # 'wav2letter_modified',

    'wav2vec2',
    'speech2text',
    'deepspeech2',
    ]
threshold = 0.5
mVocs = True
lmbda_column = 'opt_lmbda'
corr_column = 'mVocs_normalized_test_cc'
num_models = len(model_names)
fig, axes = plt.subplots(1, num_models, figsize=(12, 6), sharey=True)
lag = 200
bw = 50
for i, model_name in enumerate(model_names):
    identifier = f'ucsf_mVocs_trf_lags{lag}_bw{bw}_regression_improved'
    strf_obj = Correlations(model_name + '_' + identifier)
    data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
    axes[i].scatter(data[lmbda_column], data[corr_column])
    axes[i].axhline(0, color='black', linestyle='--')
    axes[i].set_ylim(-0.5, 2)
    axes[i].set_xlim(-5, 15)
    axes[i].set_title(model_name)
title = "mVocs" if mVocs else "timit"
plt.suptitle(title+f", bw-{bw}, window={lag}ms,")
# Out:
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# Text(0.5, 0.98, 'mVocs, bw-50, window=200ms,')

# %%
model_names = [
    'whisper_tiny',
    # 'whisper_base',
    # 'wav2letter_modified',

    # 'wav2vec2',
    # 'speech2text',
    'deepspeech2',
    ]
threshold = 0.5
mVocs = False
lmbda_column = 'opt_lmbda'
corr_column = 'normalized_test_cc'
if mVocs:
    corr_column = 'mVocs_'+corr_column
num_models = len(model_names)
fig, axes = plt.subplots(1, num_models, figsize=(12, 6), sharey=True)
lag = 200
bw = 50
for i, model_name in enumerate(model_names):
    identifier = f'ucsf_timit_trf_lags{lag}_bw{bw}_regression_improved'
    strf_obj = Correlations(model_name + '_' + identifier)
    data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
    axes[i].scatter(data[lmbda_column], data[corr_column])
    axes[i].axhline(0, color='black', linestyle='--')
    axes[i].set_ylim(-0.5, 2)
    axes[i].set_xlim(-5, 15)
    axes[i].set_title(model_name)
title = "mVocs" if mVocs else "timit"
plt.suptitle(title+f", bw-{bw}, window={lag}ms,")
# Out:
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# Text(0.5, 0.98, 'timit, bw-50, window=200ms,')

# %% [markdown]
# #### old results..

# %%
model_name = 'speech2text'
threshold = 0.5
mVocs = True
lmbda_column = 'opt_lmbda'
corr_column = 'mVocs_normalized_test_cc'
fig, axes = plt.subplots(1, 3, figsize=(12, 6), sharey=True)
i = 0
identifier = 'ucsf_mVocs_trf_lags50_bw50_plos_review'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)

i=1
identifier = 'mVocs_trf_lags300_bw50_naplib_matched'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)

i=2
identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)
# Out:
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# (-0.5, 2.0)

# %%
model_name = 'wav2vec2'
threshold = 0.5
mVocs = True
lmbda_column = 'opt_lmbda'
corr_column = 'mVocs_normalized_test_cc'
fig, axes = plt.subplots(1, 3, figsize=(12, 6), sharey=True)
i = 0
identifier = 'ucsf_mVocs_trf_lags50_bw50_plos_review'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)

i=1
identifier = 'mVocs_trf_lags300_bw50_naplib_matched'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)

i=2
identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved'
strf_obj = Correlations(model_name + '_' + identifier)
data = strf_obj.get_highly_tuned_channels(strf_obj.data, threshold=threshold, mVocs=mVocs)
axes[i].scatter(data[lmbda_column], data[corr_column])
axes[i].axhline(0, color='black', linestyle='--')
axes[i].set_ylim(-0.5, 2)
# axes[i].hist(strf_obj.data['lmbda'])
# axes[i].set_xlim(-5, 10)
# Out:
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# (-0.5, 2.0)

# %% [markdown]
# ### Hierarchy..

# %% [markdown]
# #### timit

# %%
model_names = [
	'deepspeech2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'wav2vec2',
	'wav2letter_modified',
	]
identifier = 'ucsf_timit_trf_lags200_bw50_regression_improved'
bin_width = 50
mVocs = False
tikzplots.plot_peak_layer_histograms_all_models(
	model_names,
	identifier,
	bin_width=bin_width,
	mVocs=mVocs,
	threshold = threshold,
	save_tikz=save_tikz,
	fontsize=20,
	figsize=(2.5,2),
	)
# Out:
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# /tmp/ipykernel_429784/57998649.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms_all_models(
# /tmp/ipykernel_429784/57998649.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms_all_models(
# INFO:Extracting column: normalized_test_cc
# INFO:Filtering 'normalizer' using multiple of 0.500 with std dev ...
# ...

# %% [markdown]
# #### mVocs

# %%
model_names = [
	'deepspeech2',
	'speech2text',
	'whisper_tiny',
	'whisper_base',
	'wav2vec2',
	'wav2letter_modified',
	]
identifier = 'ucsf_mVocs_trf_lags200_bw50_regression_improved'
bin_width = 50
mVocs = True
tikzplots.plot_peak_layer_histograms_all_models(
	model_names,
	identifier,
	bin_width=bin_width,
	mVocs=mVocs,
	threshold = threshold,
	save_tikz=save_tikz,
	fontsize=20,
	figsize=(2.5,2),
	)
# Out:
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# INFO:Extracting column: mVocs_normalized_test_cc
# INFO:Filtering 'mVocs_normalizer' using multiple of 0.500 with std dev ...
# /tmp/ipykernel_3634446/1185170516.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms_all_models(
# /tmp/ipykernel_3634446/1185170516.py:12: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   tikzplots.plot_peak_layer_histograms_all_models(
# INFO:Extracting column: mVocs_normalized_test_cc
# ...
